# %%
from image_processing_pipeline import Visualiser

# %%
from image_processing_pipeline.utils.generate_sample_data import (
  SampleDataConfig,
  generate_gaussian_field,
  add_background,
  generate_cell_frame,
  generate_structures,
  generate_sample_frame,
)

config = SampleDataConfig()

# %%
data = generate_gaussian_field(config)
Visualiser.show_image_stack(data)

# %%
data_with_background = add_background(data, config)
Visualiser.show_image_stack(data_with_background)

# %%
frame, inside = generate_cell_frame(config)
Visualiser.show_image_stack(data_with_background * inside + frame)

# %%
structures = generate_structures(config)
Visualiser.show_image_stack(structures)

# %%
structures = generate_sample_frame(config)
Visualiser.show_image_stack(structures)
